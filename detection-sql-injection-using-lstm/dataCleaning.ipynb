# %%
# !ls
# Out:
# drive  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd 'drive/MyDrive/TA-10'
# Out:
# /content/drive/MyDrive/TA-10

# %%
import pandas as pd

# %%
# Read Dataset
df = pd.read_excel('dataset/dataset.xlsx')
df.tail()
# Out:
#                                                 Sentence  Type
# 41001                         v_attr4 VARCHAR2 ( 4000 )      0
# 41002                         v_attr5 VARCHAR2 ( 4000 )      0
# 41003                         v_command VARCHAR2 ( 32 )      0
# 41004                     variable name varchar2 ( 30 )      0
# 41005  with agents ( name, salary )  as   (  (  selec...     0

# %%
# Info Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41006 entries, 0 to 41005
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  35513 non-null  object
#  1   Type      41006 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 640.8+ KB

# %%
df.count()
# Out:
# Sentence    35513
# Type        41006
# dtype: int64

# %%
# Check There are Data Null or Not
df.isnull().any()
# Out:
# Sentence     True
# Type        False
# dtype: bool

# %%
sentenceRemoveIndex = df[df['Sentence'].isnull()].index
print(sentenceRemoveIndex)
# Out:
# Int64Index([ 3925,  3926,  3927,  3928,  3929,  3930,  3931,  3932,  3933,
#              3934,
#             ...
#             38763, 38764, 39101, 39380, 39381, 39604, 39840, 39841, 39845,
#             39846],
#            dtype='int64', length=5493)

# %%
df.isnull().sum()
# Out:
# Sentence    5493
# Type           0
# dtype: int64

# %%
df.drop((df.index[sentenceRemoveIndex.tolist()]), inplace=True)

# %%
df.isnull().any()
# Out:
# Sentence    False
# Type        False
# dtype: bool

# %%
df.count()
# Out:
# Sentence    35513
# Type        35513
# dtype: int64

# %%
df.duplicated().any()
# Out:
# True

# %%
sum(df.duplicated())
# Out:
# 17463

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# False

# %%
# Info Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18050 entries, 0 to 41005
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  18050 non-null  object
#  1   Type      18050 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 423.0+ KB

# %%
df.head().T
# Out:
#                                     0                                  1  \
# Sentence  /dvwa/vulnerabilities/csrf/  /dvwa/instructions.php?doc=readme
# Type                                0                                  0
#
#                                2                                          3  \
# Sentence  /dvwa/instructions.php  /dvwa/instructions.php?doc=PHPIDS-license
# Type                           0                                          0
#
#                                     4
# Sentence  /dvwa/vulnerabilities/exec/
# Type                                0

# %%
df.to_csv('dataset/datasetClean.csv', index=False)
